# %% [markdown]
# <a href="https://colab.research.google.com/github/jjjjpr/archive/blob/main/2_creating_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_02
# Out:
# /content/drive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_02

# %%
pwd
# Out:
# '/content/drive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_02'

# %%
ls
# Out:
# 1-pandas_data_structures.ipynb               5-subsetting_data.ipynb
# 2-creating_dataframes.ipynb                  6-adding_and_removing_data.ipynb
# 3-making_dataframes_from_api_requests.ipynb  data/
# 4-inspecting_dataframes.ipynb                README.md

# %%
import pandas as pd

data = {
    "Name" : ["정서현", "이강규", "혜열정", "지민경"],
    "Hobby" : ["영화보기", "클라이밍", "게임", "맛집탐방"],
    "Nationality" : ["korean", "korean", "chinese", "korean"],
    "학과" : ["응통", "기계", "응통", "응통"],
    "학번" : ["19", "20", "20", "19"],
    "지역" : ["서울", "서울", "서울", "인천"]
}

team_df = pd.DataFrame(data)
team_df
# Out:
#   Name Hobby Nationality  학과  학번  지역
# 0  정서현  영화보기      korean  응통  19  서울
# 1  이강규  클라이밍      korean  기계  20  서울
# 2  혜열정    게임     chinese  응통  20  서울
# 3  지민경  맛집탐방      korean  응통  19  인천

# %%
new_index = range(101, 101+ len(team_df))

team_df.index = new_index
team_df
# Out:
#     Name Hobby Nationality  학과  학번  지역
# 101  정서현  영화보기      korean  응통  19  서울
# 102  이강규  클라이밍      korean  기계  20  서울
# 103  혜열정    게임     chinese  응통  20  서울
# 104  지민경  맛집탐방      korean  응통  19  인천

# %%
df = team_df

df.to_csv("data/Task2.csv", index= False)

# %%
df = pd.read_csv("data/Task2.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of   Name Hobby Nationality  학과  학번  지역
# 0  정서현  영화보기      korean  응통  19  서울
# 1  이강규  클라이밍      korean  기계  20  서울
# 2  혜열정    게임     chinese  응통  20  서울
# 3  지민경  맛집탐방      korean  응통  19  인천>
